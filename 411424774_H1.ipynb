# %% [markdown]
# <a href="https://colab.research.google.com/github/yiru1210/2006-9-15/blob/main/411424774_H1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=int(input("請輸入目前金幣數量"))
y=int(input("請輸入獲得金幣數量:"))
z = x+y
print(f"任務完成！你現在有{z}枚金幣 ")
# Out:
# 請輸入目前金幣數量500
# 請輸入獲得金幣數量:50
# 任務完成！你現在有550枚金幣
